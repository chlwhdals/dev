# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split  # Import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images, val_images, train_labels, val_labels 
= train_test_split(train_images, train_labels, test_size=0.3, random_state=42)

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])
# Out:
# WARNING:tensorflow:From C:\Users\human\.conda\envs\py310tf2\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\human\.conda\envs\py310tf2\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\human\.conda\envs\py310tf2\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\human\.conda\envs\py310tf2\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3423 - accuracy: 0.9010 - val_loss: 0.1772 - val_accuracy: 0.9497
# Epoch 2/5
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1710 - accuracy: 0.9489 - val_loss: 0.1320 - val_accuracy: 0.9623
# Epoch 3/5
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.1264 - accuracy: 0.9624 - val_loss: 0.1103 - val_accuracy: 0.9674
# Epoch 4/5
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9736
# Test accuracy: 0.9735999703407288

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# train.py

import tensorflow as tf
from tensorflow.keras.datasets import mnist

# MNIST 데이터셋 로드
(train_images, train_labels), _ = mnist.load_data()

# 데이터 전처리
train_images = train_images / 255.0

# 모델 훈련
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0484 - accuracy: 0.9840
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0448 - accuracy: 0.9847
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0409 - accuracy: 0.9858
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0391 - accuracy: 0.9869
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0356 - accuracy: 0.9879

# %%
# !git init
# !git add model.py train.py
# !git commit -m "Initial commit"
# !git remote add origin https://github.com/sdfgsafa/aaaa.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in D:/python-workspace/.git/
# fatal: pathspec 'model.py' did not match any files
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
# 	"01.\353\263\200\354\210\230.ipynb"
# 	"02.01 \354\236\220\353\243\214\355\230\225 \354\274\200\354\235\264\354\212\244.ipynb"
# 	02.02 chatbot.ipynb
# 	"02.02 \354\206\214\352\270\210\353\254\274 \353\206\215\353\217\204.ipynb"
# 	06score.csv
# 	"11. \352\260\235\354\262\2642.ipynb"
# 	Deepruning-workspace/
# 	Untitled Folder/
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled2.ipynb
# 	Untitled3.ipynb
# 	Untitled4.ipynb
# 	Untitled5.ipynb
# 	Untitled6.ipynb
# 	Untitled7.ipynb
# 	back.gif
# 	database-workspace/
# 	dd.xlsx
# 	front.gif
# 	keyword
# 	keyword.txt
# 	ml-workspace/
# 	pygame.1.py
# 	pygame/
# 	python education.zip
# 	python education/
# 	rectangle.1.py
# 	shooting.zip
# 	shooting/
# 	test.ipynb
# ...
